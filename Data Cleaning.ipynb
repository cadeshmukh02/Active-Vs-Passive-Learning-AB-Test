# %%
import pandas as pd

pre_survey_complete = pd.read_csv('/content/StubHub Case Notes!_complete.csv')
pre_survey_incomplete = pd.read_csv('/content/StubHub Case Notes!_incomplete.csv')
post_survey_complete = pd.read_csv('/content/Post Class Survey_complete.csv')
post_survey_incomplete = pd.read_csv('/content/Post Class Survey_incomplete.csv')

# %%
pre_survey_complete.Group.value_counts()
# Out:
# Group
# 0                       31
# 1                       24
# Group                    1
# {"ImportId":"Group"}     1
# Name: count, dtype: int64

# %%
post_survey_complete.Group.value_counts()
# Out:
# Group
# 0                       31
# 1                       27
# Group                    1
# {"ImportId":"Group"}     1
# Name: count, dtype: int64

# %%
pre_survey_complete.RecipientFirstName.value_counts()
# Out:
# RecipientFirstName
# Recipient First Name                 1
# {"ImportId":"recipientFirstName"}    1
# Name: count, dtype: int64

# %%
pre_survey_incomplete
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/Ne...
# 2                                 2025-02-19 11:32:54
# 3                                 2025-02-19 14:53:10
# 4                                 2025-02-19 14:55:34
# 5                                 2025-02-19 18:34:09
# 6                                 2025-02-19 18:39:03
# 7                                 2025-02-19 18:41:57
# 8                                 2025-02-19 19:03:32
# 9                                 2025-02-19 21:14:47
# 10                                2025-02-19 23:38:24
# 11                                2025-02-19 23:48:36
# 12                                2025-02-19 23:50:39
# 13                                2025-02-19 23:50:43
# 14                                2025-02-19 23:56:43
# 15                                2025-02-20 01:59:07
# ...

# %%
pre_survey_complete = pre_survey_complete.drop(columns=['Status','IPAddress','StartDate','EndDate','Finished','RecordedDate','ResponseId','RecipientLastName'])
pre_survey_complete = pre_survey_complete.drop(columns=['ExternalReference','LocationLatitude','LocationLongitude','UserLanguage',])
pre_survey_complete = pre_survey_complete.drop(columns=['Progress','RecipientFirstName'])
pre_survey_complete = pre_survey_complete.drop([0, 1], axis=0).reset_index(drop=True)
pre_survey_complete
# Out:
#    Duration (in seconds)   RecipientEmail DistributionChannel      Q1   Q2  \
# 0                     57    rbubis@bu.edu           anonymous  Female  Yes
# 1                    144   shivnag@bu.edu           anonymous    Male  Yes
# 2                    605     seven@bu.edu           anonymous  Female  Yes
# 3                   5904  baratz00@bu.edu           anonymous    Male  Yes
# 4                    143      mweb@bu.edu           anonymous    Male  Yes
# 5                     54    ohmsri@bu.edu           anonymous    Male  Yes
# 6                    160  bjwilcox@bu.edu           anonymous    Male  Yes
# 7                    390    yy3216@bu.edu           anonymous  Female  Yes
# 8                  15897  jhuangbp@bu.edu           anonymous    Male  Yes
# 9                    261    ohmsri@bu.edu           anonymous    Male  Yes
# 10                  6793    jrashi@bu.edu           anonymous  Female  Yes
# ...

# %%
pre_survey_complete.to_csv('cleaned_pre_survey_complete.csv')

# %%
pre_survey_incomplete = pre_survey_incomplete.drop(columns=['Status','IPAddress','StartDate','EndDate','Finished','RecordedDate','ResponseId','RecipientLastName'])
pre_survey_incomplete = pre_survey_incomplete.drop(columns=['ExternalReference','LocationLatitude','LocationLongitude','UserLanguage',])
pre_survey_incomplete = pre_survey_incomplete.drop(columns=['RecipientFirstName'])
pre_survey_incomplete = pre_survey_incomplete.drop([0, 1], axis=0).reset_index(drop=True)
pre_survey_incomplete
# Out:
#    Progress Duration (in seconds)   RecipientEmail DistributionChannel  \
# 0         0                     7              NaN           anonymous
# 1        22                  6152   fradkin@bu.edu           anonymous
# 2        63                 32540   sohamss@bu.edu           anonymous
# 3        88                 69706       ckv@bu.edu           anonymous
# 4         0                    13  baratz00@bu.edu           anonymous
# 5        38                   144    zppz24@bu.edu           anonymous
# 6         0                    30     yycyy@bu.edu           anonymous
# 7         0                    37   kaylach@bu.edu           anonymous
# 8         0                 51456    glennc@bu.edu           anonymous
# 9        19                    42  kaushiki@bu.edu           anonymous
# 10        0                 27903   atishay@bu.edu           anonymous
# 11       19                    74  pranayab@bu.edu           anonymous
# ...

# %%
pre_survey_incomplete.to_csv('cleaned_pre_survey_incomplete.csv')

# %%
post_survey_complete = post_survey_complete.drop(columns=['Status','IPAddress','StartDate','EndDate','Finished','RecordedDate','ResponseId','RecipientLastName'])
post_survey_complete = post_survey_complete.drop(columns=['ExternalReference','LocationLatitude','LocationLongitude','UserLanguage',])
post_survey_complete = post_survey_complete.drop(columns=['Progress','RecipientFirstName'])
post_survey_complete = post_survey_complete.drop([0, 1], axis=0).reset_index(drop=True)
post_survey_complete
# Out:
#    Duration (in seconds)   RecipientEmail DistributionChannel Q11_1 Q11_3  \
# 0                     39    nehags@bu.edu             preview   NaN   NaN
# 1                     25   whj0807@bu.edu                  qr   100    72
# 2                     35  jacobr59@bu.edu                  qr    59    89
# 3                     38    rbubis@bu.edu                  qr    50    50
# 4                     34  pranayab@bu.edu                  qr    95   100
# 5                     42    sanjal@bu.edu                  qr    17   100
# 6                     49       ymk@bu.edu                  qr    32    68
# 7                     53  bjwilcox@bu.edu                  qr    15   100
# 8                     46    jrashi@bu.edu                  qr    37     0
# 9                     61      mweb@bu.edu                  qr    30    85
# 10                    56   divyesh@bu.edu                  qr    61    73
# 11                    51   aryan16@bu.edu                  qr    40    19
# ...

# %%
post_survey_complete.to_csv('cleaned_post_survey_complete.csv')

# %%
post_survey_incomplete = post_survey_incomplete.drop(columns=['Status','IPAddress','StartDate','EndDate','Finished','RecordedDate','ResponseId','RecipientLastName'])
post_survey_incomplete = post_survey_incomplete.drop(columns=['ExternalReference','LocationLatitude','LocationLongitude','UserLanguage',])
post_survey_incomplete = post_survey_incomplete.drop(columns=['Progress','RecipientFirstName'])
post_survey_incomplete = post_survey_incomplete.drop([0, 1], axis=0).reset_index(drop=True)
post_survey_incomplete
# Out:
#    Duration (in seconds)   RecipientEmail DistributionChannel Q11_1 Q11_3  \
# 0                    128    nehags@bu.edu           anonymous   NaN   NaN
# 1                     18  skong610@bu.edu                  qr   NaN   NaN
# 2                     65  asachdev@bu.edu                  qr   NaN   NaN
# 3                     10   nimisha@bu.edu                  qr   NaN   NaN
# 4                     11    yy3216@bu.edu                  qr   NaN   NaN
# 5                      6  amishask@bu.edu                  qr   NaN   NaN
# 6                     31     yycyy@bu.edu                  qr   NaN   NaN
# 7                      8   wenlin1@bu.edu                  qr   NaN   NaN
# 8                     12     beisu@bu.edu                  qr   NaN   NaN
# 9                      9  pratik77@bu.edu                  qr   NaN   NaN
# 10                    75     skant@bu.edu                  qr   NaN   NaN
# 11                     8   sidhant@bu.edu                  qr   NaN   NaN
#
# ...

# %%
post_survey_incomplete.to_csv('cleaned_post_survey_incomplete.csv')

# %%
post_survey_incomplete
# Out:
#                                             StartDate  \
# 0                                          Start Date
# 1   {"ImportId":"startDate","timeZone":"America/Ne...
# 2                                 2025-02-19 11:36:09
# 3                                 2025-02-20 10:13:07
# 4                                 2025-02-20 10:13:18
# 5                                 2025-02-20 10:13:23
# 6                                 2025-02-20 13:56:12
# 7                                 2025-02-20 13:56:18
# 8                                 2025-02-20 13:56:49
# 9                                 2025-02-20 13:56:50
# 10                                2025-02-20 13:57:17
# 11                                2025-02-20 13:58:59
# 12                                2025-02-20 14:01:44
# 13                                2025-02-20 14:01:45
#
#                                               EndDate                 Status  \
# ...

# %%
pre_survey_complete.Q1.value_counts()
# Out:
# Q1
# Male      34
# Female    21
# Name: count, dtype: int64

# %%
merged = pre_survey_complete.merge(post_survey_complete, how='inner', on='RecipientEmail')
merged
# Out:
#    Duration (in seconds)_x   RecipientEmail DistributionChannel_x      Q1  \
# 0                       57    rbubis@bu.edu             anonymous  Female
# 1                      144   shivnag@bu.edu             anonymous    Male
# 2                     5904  baratz00@bu.edu             anonymous    Male
# 3                      143      mweb@bu.edu             anonymous    Male
# 4                      160  bjwilcox@bu.edu             anonymous    Male
# 5                    15897  jhuangbp@bu.edu             anonymous    Male
# 6                     6793    jrashi@bu.edu             anonymous  Female
# 7                       60  jacobr59@bu.edu             anonymous    Male
# 8                    25583  tharfeed@bu.edu             anonymous    Male
# 9                      109    huawan@bu.edu             anonymous  Female
# 10                   27773    jylee2@bu.edu             anonymous  Female
# 11                      69    lilifu@bu.edu             anonymous    Male
# ...

# %%
merged.Group_x.value_counts()
# Out:
# Group_x
# 0    22
# 1    13
# Name: count, dtype: int64

# %%
pre_survey_incomplete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Progress               37 non-null     object
#  1   Duration (in seconds)  37 non-null     object
#  2   RecipientEmail         35 non-null     object
#  3   DistributionChannel    37 non-null     object
#  4   Q1                     15 non-null     object
#  5   Q2                     15 non-null     object
#  6   Q3_1                   15 non-null     object
#  7   Q3_3                   15 non-null     object
#  8   Q1.1                   7 non-null      object
#  9   Q2.1                   5 non-null      object
#  10  Q3                     5 non-null      object
#  11  Q4                     3 non-null      object
#  12  Q5                     3 non-null      object
#  13  Q6                     3 non-null      object
# ...

# %%
pre_survey = pd.concat([pre_survey_complete, pre_survey_incomplete], axis=0, ignore_index=True)

# %%
pre_survey

rename_dict = {
    "Q1": "CVQ1_gender_bool",
    "Q2": "CVQ2_read_stubhub_case_bool",
    "Q3_1": "CVQ3_knowledge_causality_val",
    "Q3_3": "CVQ4_likeliness_participate_val",
    "Q19_1": "RQ1_understand_material_val",
    "Q19_2": "RQ2_remember_tomorrow_val",
    "Q20": "RQ3_active_involvement_val",
    "Q1.1": "Q1",
    "Q2.1": "Q2",
    "SC0": "Score",
    "Duration (in seconds)": "pre_class_time_spent",
    "DistributionChannel" : "pre_class_DistributionChannel",
    "Group" : "Treatment"
}

# Apply renaming
pre_survey = pre_survey.rename(columns=rename_dict)
pre_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pre_class_time_spent             92 non-null     object
#  1   RecipientEmail                   90 non-null     object
#  2   pre_class_DistributionChannel    92 non-null     object
#  3   CVQ1_gender_bool                 70 non-null     object
#  4   CVQ2_read_stubhub_case_bool      70 non-null     object
#  5   CVQ3_knowledge_causality_val     70 non-null     object
#  6   CVQ4_likeliness_participate_val  70 non-null     object
#  7   Q1                               31 non-null     object
#  8   Q2                               29 non-null     object
#  9   Q3                               29 non-null     object
#  10  Q4                               27 non-null     object
#  11  Q5                               27 non-null     object
# ...

# %%
columns_to_drop = [f"Q{i}" for i in range(1, 11)]  # Generate column names Q1 to Q10
pre_survey = pre_survey.drop(columns=[col for col in columns_to_drop if col in pre_survey.columns], errors='ignore')
pre_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pre_class_time_spent             92 non-null     object
#  1   RecipientEmail                   90 non-null     object
#  2   pre_class_DistributionChannel    92 non-null     object
#  3   CVQ1_gender_bool                 70 non-null     object
#  4   CVQ2_read_stubhub_case_bool      70 non-null     object
#  5   CVQ3_knowledge_causality_val     70 non-null     object
#  6   CVQ4_likeliness_participate_val  70 non-null     object
#  7   RQ1_understand_material_val      55 non-null     object
#  8   RQ2_remember_tomorrow_val        55 non-null     object
#  9   RQ3_active_involvement_val       55 non-null     object
#  10  Score                            92 non-null     object
#  11  Treatment                        90 non-null     object
# ...

# %%
pre_survey.to_csv("pre_survey.csv", index=False)

# %%
import pandas as pd
pre_survey = pd.read_csv("pre_survey.csv")

# %%
pre_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pre_class_time_spent             92 non-null     int64
#  1   RecipientEmail                   90 non-null     object
#  2   pre_class_DistributionChannel    92 non-null     object
#  3   CVQ1_gender_bool                 70 non-null     object
#  4   CVQ2_read_stubhub_case_bool      70 non-null     object
#  5   CVQ3_knowledge_causality_val     70 non-null     float64
#  6   CVQ4_likeliness_participate_val  70 non-null     float64
#  7   RQ1_understand_material_val      55 non-null     float64
#  8   RQ2_remember_tomorrow_val        55 non-null     float64
#  9   RQ3_active_involvement_val       55 non-null     object
#  10  Score                            92 non-null     int64
#  11  Treatment                        90 non-null     float64
# ...

# %%
pre_survey["Progress"] = pre_survey["Progress"].fillna(100)

# %%
pre_survey["pre_class_incomplete"] = pre_survey["Progress"].apply(lambda x: 0 if x==100 else 1)

# %%
pre_survey["CVQ1_gender_bool"] = pre_survey["CVQ1_gender_bool"].map({"Male": 1, "Female": 0})
pre_survey
# Out:
#     pre_class_time_spent   RecipientEmail pre_class_DistributionChannel  \
# 0                     57    rbubis@bu.edu                     anonymous
# 1                    144   shivnag@bu.edu                     anonymous
# 2                    605     seven@bu.edu                     anonymous
# 3                   5904  baratz00@bu.edu                     anonymous
# 4                    143      mweb@bu.edu                     anonymous
# ..                   ...              ...                           ...
# 87                    12     beisu@bu.edu                            qr
# 88                     8     cleat@bu.edu                            qr
# 89                    20   jastsai@bu.edu                            qr
# 90                    14  jhuangbp@bu.edu                            qr
# 91                    10   shawn17@bu.edu                            qr
#
#     CVQ1_gender_bool CVQ2_read_stubhub_case_bool  \
# 0                0.0                         Yes
# ...

# %%
pre_survey["CVQ2_read_stubhub_case_bool"] = pre_survey["CVQ2_read_stubhub_case_bool"].map({"Yes": 1, "No": 0})
pre_survey
# Out:
#     pre_class_time_spent   RecipientEmail pre_class_DistributionChannel  \
# 0                     57    rbubis@bu.edu                     anonymous
# 1                    144   shivnag@bu.edu                     anonymous
# 2                    605     seven@bu.edu                     anonymous
# 3                   5904  baratz00@bu.edu                     anonymous
# 4                    143      mweb@bu.edu                     anonymous
# ..                   ...              ...                           ...
# 87                    12     beisu@bu.edu                            qr
# 88                     8     cleat@bu.edu                            qr
# 89                    20   jastsai@bu.edu                            qr
# 90                    14  jhuangbp@bu.edu                            qr
# 91                    10   shawn17@bu.edu                            qr
#
#     CVQ1_gender_bool  CVQ2_read_stubhub_case_bool  \
# 0                0.0                          1.0
# ...

# %%
pre_survey["RQ3_active_involvement_val"] = pre_survey["RQ3_active_involvement_val"].map({"Yes": 2, "Somewhat": 1, "No": 0})
pre_survey
# Out:
#     pre_class_time_spent   RecipientEmail pre_class_DistributionChannel  \
# 0                     57    rbubis@bu.edu                     anonymous
# 1                    144   shivnag@bu.edu                     anonymous
# 2                    605     seven@bu.edu                     anonymous
# 3                   5904  baratz00@bu.edu                     anonymous
# 4                    143      mweb@bu.edu                     anonymous
# ..                   ...              ...                           ...
# 87                    12     beisu@bu.edu                            qr
# 88                     8     cleat@bu.edu                            qr
# 89                    20   jastsai@bu.edu                            qr
# 90                    14  jhuangbp@bu.edu                            qr
# 91                    10   shawn17@bu.edu                            qr
#
#     CVQ1_gender_bool  CVQ2_read_stubhub_case_bool  \
# 0                0.0                          1.0
# ...

# %%
pre_survey[pre_survey["Complete"]==1].RQ3_active_involvement_val.value_counts()
# Out:
# RQ3_active_involvement_val
# 1.0    30
# 2.0    23
# 0.0     2
# Name: count, dtype: int64

# %% [markdown]
# ANALYSIS

# %%
pre_survey
# Out:
#     pre_class_time_spent   RecipientEmail pre_class_DistributionChannel  \
# 0                     57    rbubis@bu.edu                     anonymous
# 1                    144   shivnag@bu.edu                     anonymous
# 2                    605     seven@bu.edu                     anonymous
# 3                   5904  baratz00@bu.edu                     anonymous
# 4                    143      mweb@bu.edu                     anonymous
# ..                   ...              ...                           ...
# 87                    12     beisu@bu.edu                            qr
# 88                     8     cleat@bu.edu                            qr
# 89                    20   jastsai@bu.edu                            qr
# 90                    14  jhuangbp@bu.edu                            qr
# 91                    10   shawn17@bu.edu                            qr
#
#     CVQ1_gender_bool  CVQ2_read_stubhub_case_bool  \
# 0                0.0                          1.0
# ...

# %%
pre_survey= pre_survey[pre_survey['pre_class_DistributionChannel'] != 'preview']

# %%
pre_survey.pre_class_incomplete.value_counts()
# Out:
# pre_class_incomplete
# 0    55
# 1    37
# Name: count, dtype: int64

# %%
pre_survey = pre_survey.drop(columns=["Complete"], errors="ignore")

# %%
pre_survey.to_csv("pre_survey.csv", index=False)

# %%
import pandas as pd
post_survey_complete = pd.read_csv('/content/cleaned_post_survey_complete.csv')
post_survey_incomplete = pd.read_csv('/content/cleaned_post_survey_incomplete.csv')
pre_survey_incomplete = pd.read_csv('/content/cleaned_pre_survey_incomplete.csv')
pre_survey_complete = pd.read_csv('/content/cleaned_pre_survey_complete.csv')

# %%
post_survey_complete.head()
# Out:
#    Unnamed: 0  Duration (in seconds)   RecipientEmail DistributionChannel  \
# 0           0                     39    nehags@bu.edu             preview
# 1           1                     25   whj0807@bu.edu                  qr
# 2           2                     35  jacobr59@bu.edu                  qr
# 3           3                     38    rbubis@bu.edu                  qr
# 4           4                     34  pranayab@bu.edu                  qr
#
#    Q11_1  Q11_3  Q11_4  Q31                  Q32  Q33  Group
# 0    NaN    NaN    NaN  NaN                  NaN  NaN      1
# 1  100.0   72.0   85.0  Yes  Interactive Quizzes  NaN      0
# 2   59.0   89.0   71.0  Yes  Interactive Quizzes  NaN      0
# 3   50.0   50.0   30.0   No    Pre-written Notes  NaN      0
# 4   95.0  100.0  100.0  Yes  Interactive Quizzes  NaN      1

# %%
post_survey_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             58 non-null     int64
#  1   Duration (in seconds)  58 non-null     int64
#  2   RecipientEmail         58 non-null     object
#  3   DistributionChannel    58 non-null     object
#  4   Q11_1                  57 non-null     float64
#  5   Q11_3                  57 non-null     float64
#  6   Q11_4                  57 non-null     float64
#  7   Q31                    57 non-null     object
#  8   Q32                    57 non-null     object
#  9   Q33                    7 non-null      object
#  10  Group                  58 non-null     int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 5.1+ KB

# %%
post_survey_complete.rename(columns={'Duration (in seconds)': 'post_class_time_spent',
                                     'DistributionChannel': 'post_class_DistributionChannel',
                                     'Q31': 'post_class_willingness_to_participate',
'Q11_4': 'post_class_preparedness',
'Q11_3': 'post_class_class_participation_val',
'Q11_1': 'post_class_recall_val',
                                     'Q32':'post_class_choice',
                                     'Q33':'post_class_feedback',
                                     }, inplace=True)

# %%
post_survey_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             58 non-null     int64
#  1   post_class_time_spent                  58 non-null     int64
#  2   RecipientEmail                         58 non-null     object
#  3   post_class_DistributionChannel         58 non-null     object
#  4   post_class_recall_val                  57 non-null     float64
#  5   post_class_class_participation_val     57 non-null     float64
#  6   post_class_preparedness                57 non-null     float64
#  7   post_class_willingness_to_participate  57 non-null     object
#  8   post_class_choice                      57 non-null     object
#  9   post_class_feedback                    7 non-null      object
# ...

# %%
import numpy as np
post_survey_complete['post_class_incomplete'] = np.zeros(len(post_survey_complete))

# %%
post_survey_complete.isna().sum()
# Out:
# Unnamed: 0                                0
# post_class_time_spent                     0
# RecipientEmail                            0
# post_class_DistributionChannel            0
# post_class_recall_val                     1
# post_class_class_participation_val        1
# post_class_preparedness                   1
# post_class_willingness_to_participate     1
# post_class_choice                         1
# post_class_feedback                      51
# Group                                     0
# post_class_incomplete                     0
# dtype: int64

# %%
#identify row with nan values
post_survey_complete['post_class_DistributionChannel'] != 'preview'
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53     True
# 54     True
# 55     True
# 56     True
# 57     True
# Name: post_class_DistributionChannel, dtype: bool

# %%
post_survey_complete.drop(columns=['Unnamed: 0', 'post_class_incomplete'], inplace=True)

# %%
post_survey_incomplete.rename(columns={'Duration (in seconds)': 'post_class_time_spent',
                                     'DistributionChannel': 'post_class_DistributionChannel',
                                     'Q31': 'post_class_willingness_to_participate',
'Q11_4': 'post_class_preparedness',
'Q11_3': 'post_class_class_participation_val',
'Q11_1': 'post_class_recall_val',
                                     'Q32':'post_class_choice',
                                     'Q33':'post_class_feedback',
                                     }, inplace=True)

# %%
post_survey_incomplete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             12 non-null     int64
#  1   post_class_time_spent                  12 non-null     int64
#  2   RecipientEmail                         12 non-null     object
#  3   post_class_DistributionChannel         12 non-null     object
#  4   post_class_recall_val                  0 non-null      float64
#  5   post_class_class_participation_val     0 non-null      float64
#  6   post_class_preparedness                0 non-null      float64
#  7   post_class_willingness_to_participate  0 non-null      float64
#  8   post_class_choice                      0 non-null      float64
#  9   post_class_feedback                    0 non-null      float64
# ...

# %%
post_survey_incomplete['post_class_incomplete'] = 1

# %%
post_survey_incomplete.drop(columns=['Unnamed: 0'])
# Out:
#     post_class_time_spent   RecipientEmail post_class_DistributionChannel  \
# 0                     128    nehags@bu.edu                      anonymous
# 1                      18  skong610@bu.edu                             qr
# 2                      65  asachdev@bu.edu                             qr
# 3                      10   nimisha@bu.edu                             qr
# 4                      11    yy3216@bu.edu                             qr
# 5                       6  amishask@bu.edu                             qr
# 6                      31     yycyy@bu.edu                             qr
# 7                       8   wenlin1@bu.edu                             qr
# 8                      12     beisu@bu.edu                             qr
# 9                       9  pratik77@bu.edu                             qr
# 10                     75     skant@bu.edu                             qr
# 11                      8   sidhant@bu.edu                             qr
#
# ...

# %%
post_survey_incomplete.head()
# Out:
#    Unnamed: 0  post_class_time_spent   RecipientEmail  \
# 0           0                    128    nehags@bu.edu
# 1           1                     18  skong610@bu.edu
# 2           2                     65  asachdev@bu.edu
# 3           3                     10   nimisha@bu.edu
# 4           4                     11    yy3216@bu.edu
#
#   post_class_DistributionChannel  post_class_recall_val  \
# 0                      anonymous                    NaN
# 1                             qr                    NaN
# 2                             qr                    NaN
# 3                             qr                    NaN
# 4                             qr                    NaN
#
#    post_class_class_participation_val  post_class_preparedness  \
# 0                                 NaN                      NaN
# 1                                 NaN                      NaN
# 2                                 NaN                      NaN
# ...

# %%
post_survey_incomplete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0                             12 non-null     int64
#  1   post_class_time_spent                  12 non-null     int64
#  2   RecipientEmail                         12 non-null     object
#  3   post_class_DistributionChannel         12 non-null     object
#  4   post_class_recall_val                  0 non-null      float64
#  5   post_class_class_participation_val     0 non-null      float64
#  6   post_class_preparedness                0 non-null      float64
#  7   post_class_willingness_to_participate  0 non-null      float64
#  8   post_class_choice                      0 non-null      float64
#  9   post_class_feedback                    0 non-null      float64
# ...

# %%
post_survey = pd.concat([post_survey_complete, post_survey_incomplete], axis=0, ignore_index=True)

# %%
post_survey.rename(columns={'post_class_preparedness': 'post_class_preparedness_val', 'post_class_willingness_to_participate': 'post_class_willingness_to_participate_bool'}, inplace = True)

# %%
post_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 12 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   post_class_time_spent                       70 non-null     int64
#  1   RecipientEmail                              70 non-null     object
#  2   post_class_DistributionChannel              70 non-null     object
#  3   post_class_recall_val                       57 non-null     float64
#  4   post_class_class_participation_val          57 non-null     float64
#  5   post_class_preparedness_val                 57 non-null     float64
#  6   post_class_willingness_to_participate_bool  57 non-null     object
#  7   post_class_choice                           57 non-null     object
#  8   post_class_feedback                         7 non-null      object
#  9   Group                                       70 non-null     int64
# ...

# %%
post_survey['post_class_incomplete'].value_counts()
# Out:
# post_class_incomplete
# 1.0    12
# Name: count, dtype: int64

# %%
post_survey.isna().sum()
# Out:
# post_class_time_spent                          0
# RecipientEmail                                 0
# post_class_DistributionChannel                 0
# post_class_recall_val                         13
# post_class_class_participation_val            13
# post_class_preparedness_val                   13
# post_class_willingness_to_participate_bool    13
# post_class_choice                             13
# post_class_feedback                           63
# Group                                          0
# Unnamed: 0                                    58
# post_class_incomplete                         58
# dtype: int64

# %%
post_survey= post_survey[post_survey['post_class_DistributionChannel'] != 'preview']

# %%
post_survey['post_class_DistributionChannel'].unique()
# Out:
# array(['qr', 'anonymous'], dtype=object)

# %%
post_survey['post_class_willingness_to_participate_bool'].value_counts()
# Out:
# post_class_willingness_to_participate_bool
# 1.0    44
# 0.0    13
# Name: count, dtype: int64

# %%
post_survey['post_class_willingness_to_participate_bool'] = post_survey['post_class_willingness_to_participate_bool'].map({'Yes': 1, 'No': 0})

# %%
#post_survey.rename(columns={'post_class_preparedness': 'post_class_preparedness_val', 'post_class_willingness_to_participate': 'post_class_willingness_to_participate_bool'}, inplace = True)

# %%
post_survey.drop(columns=['Unnamed: 0'], inplace=True)

# %%
post_survey
# Out:
#     post_class_time_spent   RecipientEmail post_class_DistributionChannel  \
# 1                      25   whj0807@bu.edu                             qr
# 2                      35  jacobr59@bu.edu                             qr
# 3                      38    rbubis@bu.edu                             qr
# 4                      34  pranayab@bu.edu                             qr
# 5                      42    sanjal@bu.edu                             qr
# ..                    ...              ...                            ...
# 65                      8   wenlin1@bu.edu                             qr
# 66                     12     beisu@bu.edu                             qr
# 67                      9  pratik77@bu.edu                             qr
# 68                     75     skant@bu.edu                             qr
# 69                      8   sidhant@bu.edu                             qr
#
#     post_class_recall_val  post_class_class_participation_val  \
# ...

# %%
post_survey["post_class_incomplete"] = post_survey["post_class_incomplete"].fillna(0)

# %%
post_survey
# Out:
#     post_class_time_spent   RecipientEmail post_class_DistributionChannel  \
# 1                      25   whj0807@bu.edu                             qr
# 2                      35  jacobr59@bu.edu                             qr
# 3                      38    rbubis@bu.edu                             qr
# 4                      34  pranayab@bu.edu                             qr
# 5                      42    sanjal@bu.edu                             qr
# ..                    ...              ...                            ...
# 65                      8   wenlin1@bu.edu                             qr
# 66                     12     beisu@bu.edu                             qr
# 67                      9  pratik77@bu.edu                             qr
# 68                     75     skant@bu.edu                             qr
# 69                      8   sidhant@bu.edu                             qr
#
#     post_class_recall_val  post_class_class_participation_val  \
# ...

# %%
post_survey.to_csv("post_survey.csv", index=False)

# %%
merged_complete = pre_survey[pre_survey["pre_class_incomplete"] == 0].merge(post_survey[post_survey["post_class_incomplete"] == 0], how='inner', on='RecipientEmail')

# %%
merged_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 23 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   pre_class_time_spent                        35 non-null     int64
#  1   RecipientEmail                              35 non-null     object
#  2   pre_class_DistributionChannel               35 non-null     object
#  3   CVQ1_gender_bool                            35 non-null     float64
#  4   CVQ2_read_stubhub_case_bool                 35 non-null     float64
#  5   CVQ3_knowledge_causality_val                35 non-null     float64
#  6   CVQ4_likeliness_participate_val             35 non-null     float64
#  7   RQ1_understand_material_val                 35 non-null     float64
#  8   RQ2_remember_tomorrow_val                   35 non-null     float64
# ...

# %%
merged_complete.drop(columns=['Group'], inplace=True)

# %%
merged_complete.to_csv("Merged_survey.csv", index= False)

# %%
pre_survey_complete = pre_survey[pre_survey["pre_class_incomplete"] == 0]
pre_survey_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 0 to 54
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pre_class_time_spent             55 non-null     int64
#  1   RecipientEmail                   55 non-null     object
#  2   pre_class_DistributionChannel    55 non-null     object
#  3   CVQ1_gender_bool                 55 non-null     float64
#  4   CVQ2_read_stubhub_case_bool      55 non-null     float64
#  5   CVQ3_knowledge_causality_val     55 non-null     float64
#  6   CVQ4_likeliness_participate_val  55 non-null     float64
#  7   RQ1_understand_material_val      55 non-null     float64
#  8   RQ2_remember_tomorrow_val        55 non-null     float64
#  9   RQ3_active_involvement_val       55 non-null     float64
#  10  Score                            55 non-null     int64
#  11  Treatment                        55 non-null     float64
# ...

# %%
pre_survey_complete.to_csv("pre_survey_complete.csv", index=False)

# %%
pre_survey.to_csv("pre_survey.csv", index=False)
post_survey.to_csv("post_survey.csv", index=False)
